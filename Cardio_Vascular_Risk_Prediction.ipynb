# %% [markdown]
# <a href="https://colab.research.google.com/github/SudoAnirudh/Cardio-Vascular-Risk-Prediction/blob/master/Cardio_Vascular_Risk_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Load the data
#
# ### Subtask:
# Load the CSV file into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# The first step is to import the pandas library to work with DataFrames and then load the CSV file into a DataFrame and display its head to verify the loading.

# %%
import pandas as pd

df = pd.read_csv('/content/1730285224-data_cardiovascular_risk.csv')
display(df.head())
# Out:
#    id  age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   0   64        2.0   F        YES         3.0     0.0                0
# 1   1   36        4.0   M         NO         0.0     0.0                0
# 2   2   46        1.0   F        YES        10.0     0.0                0
# 3   3   50        1.0   M        YES        20.0     0.0                0
# 4   4   64        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0    NaN       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# ...

# %% [markdown]
# ## Explore the data
#
# ### Subtask:
# Explore the data by displaying the first few rows, checking the data types, and looking for missing values.

# %% [markdown]
# **Reasoning**:
# Display the first few rows, data types, and missing values of the dataframe.

# %%
display(df.head())
display(df.info())
display(df.isnull().sum())
# Out:
#    id  age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   0   64        2.0   F        YES         3.0     0.0                0
# 1   1   36        4.0   M         NO         0.0     0.0                0
# 2   2   46        1.0   F        YES        10.0     0.0                0
# 3   3   50        1.0   M        YES        20.0     0.0                0
# 4   4   64        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0    NaN       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# ...

# %% [markdown]
# ## Analyze the data
#
# ### Subtask:
# Perform some basic analysis, such as descriptive statistics or value counts for relevant columns.

# %% [markdown]
# **Reasoning**:
# Calculate and display descriptive statistics for numerical columns and value counts for categorical and target columns as requested in the instructions.

# %%
display(df.describe())
display(df['sex'].value_counts())
display(df['is_smoking'].value_counts())
display(df['TenYearCHD'].value_counts())
# Out:
#                 id          age    education   cigsPerDay       BPMeds  \
# count  3390.000000  3390.000000  3303.000000  3368.000000  3346.000000
# mean   1694.500000    49.542183     1.970936     9.069477     0.029886
# std     978.753033     8.592878     1.019081    11.879078     0.170299
# min       0.000000    32.000000     1.000000     0.000000     0.000000
# 25%     847.250000    42.000000     1.000000     0.000000     0.000000
# 50%    1694.500000    49.000000     2.000000     0.000000     0.000000
# 75%    2541.750000    56.000000     3.000000    20.000000     0.000000
# max    3389.000000    70.000000     4.000000    70.000000     1.000000
#
#        prevalentStroke  prevalentHyp     diabetes      totChol       sysBP  \
# count      3390.000000   3390.000000  3390.000000  3352.000000  3390.00000
# mean          0.006490      0.315339     0.025664   237.074284   132.60118
# std           0.080309      0.464719     0.158153    45.247430    22.29203
# ...

# %% [markdown]
# ## Visualize the data
#
# ### Subtask:
# Create some visualizations to understand the data distribution and relationships between variables.

# %% [markdown]
# **Reasoning**:
# Create the requested visualizations to understand the data distribution and relationships between variables.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Histogram for 'age'
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='age', kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# 2. Bar plot for 'TenYearCHD'
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='TenYearCHD')
plt.title('Distribution of TenYearCHD (10-Year Coronary Heart Disease)')
plt.xlabel('TenYearCHD (0: No, 1: Yes)')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No CHD', 'Yes CHD'])
plt.show()

# 3. Scatter plot for 'sysBP' and 'diaBP'
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='sysBP', y='diaBP', alpha=0.6)
plt.title('Relationship between Systolic and Diastolic Blood Pressure')
plt.xlabel('Systolic Blood Pressure (sysBP)')
plt.ylabel('Diastolic Blood Pressure (diaBP)')
plt.show()

# 4. Box plot for 'BMI' grouped by 'TenYearCHD'
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='TenYearCHD', y='BMI')
plt.title('Distribution of BMI by TenYearCHD Outcome')
plt.xlabel('TenYearCHD (0: No, 1: Yes)')
plt.ylabel('Body Mass Index (BMI)')
plt.xticks(ticks=[0, 1], labels=['No CHD', 'Yes CHD'])
plt.show()

# 5. Countplot for 'is_smoking' for each 'TenYearCHD' outcome
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='TenYearCHD', hue='is_smoking')
plt.title('Distribution of Smoking Status by TenYearCHD Outcome')
plt.xlabel('TenYearCHD (0: No, 1: Yes)')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No CHD', 'Yes CHD'])
plt.legend(title='Is Smoking')
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The dataset contains information on 3390 individuals.
# *   Several columns have missing values, most notably `glucose` (304 missing values), `education` (87 missing values), and `BPMeds` (44 missing values).
# *   The dataset includes more females (1923) than males (1467).
# *   The number of smokers (1687) is similar to the number of non-smokers (1703).
# *   There is a significant class imbalance in the target variable `TenYearCHD`, with 2879 individuals not developing coronary heart disease compared to 511 who do.
# *   Visualizations suggest a positive correlation between systolic and diastolic blood pressure (`sysBP` and `diaBP`).
# *   The distribution of `BMI` appears to be similar for individuals who did and did not develop coronary heart disease based on the box plot.
# *   The countplot for `is_smoking` by `TenYearCHD` outcome can provide insights into the relationship between smoking and the risk of developing coronary heart disease.
#
# ### Insights or Next Steps
#
# *   Address the missing values through imputation or removal before further analysis or model building.
# *   Consider techniques to handle the class imbalance in the `TenYearCHD` variable when building predictive models.

# %% [markdown]
# # Task
# Analyze the file "1730285224-data_cardiovascular_risk.csv" to predict the ten-year risk of coronary heart disease (`TenYearCHD`).

# %% [markdown]
# ## Handle missing values
#
# ### Subtask:
# Impute or remove missing values from the dataset.

# %% [markdown]
# **Reasoning**:
# Identify columns with missing values and impute missing values in numerical columns with the mean.

# %%
missing_values = df.isnull().sum()
print("Missing values before imputation:")
print(missing_values[missing_values > 0])

numerical_cols_with_missing = ['education', 'cigsPerDay', 'BPMeds', 'totChol', 'BMI', 'heartRate', 'glucose']

for col in numerical_cols_with_missing:
    if col in df.columns:
        df[col].fillna(df[col].mean(), inplace=True)

print("\nMissing values after imputation:")
print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Missing values before imputation:
# education      87
# cigsPerDay     22
# BPMeds         44
# totChol        38
# BMI            14
# heartRate       1
# glucose       304
# dtype: int64
#
# Missing values after imputation:
# Series([], dtype: int64)
# /tmp/ipython-input-1662863383.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)

# %% [markdown]
# ## Handle categorical features
#
# ### Subtask:
# Encode categorical variables like 'sex' and 'is_smoking'.

# %% [markdown]
# **Reasoning**:
# Encode the categorical variables 'sex' and 'is_smoking' using one-hot encoding and display the head of the modified DataFrame.

# %%
df_encoded = pd.get_dummies(df, columns=['sex', 'is_smoking'], drop_first=True)
display(df_encoded.head())
# Out:
#    id  age  education  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  \
# 0   0   64        2.0         3.0     0.0                0             0
# 1   1   36        4.0         0.0     0.0                0             1
# 2   2   46        1.0        10.0     0.0                0             0
# 3   3   50        1.0        20.0     0.0                0             1
# 4   4   64        1.0        30.0     0.0                0             0
#
#    diabetes  totChol  sysBP  diaBP        BMI  heartRate  glucose  TenYearCHD  \
# 0         0    221.0  148.0   85.0  25.794964       90.0     80.0           1
# 1         0    212.0  168.0   98.0  29.770000       72.0     75.0           0
# 2         0    250.0  116.0   71.0  20.350000       88.0     94.0           0
# 3         0    233.0  158.0   88.0  28.260000       68.0     94.0           1
# 4         0    241.0  136.5   85.0  26.420000       70.0     77.0           0
#
#    sex_M  is_smoking_YES
# 0  False            True
# ...

# %% [markdown]
# ## Address class imbalance
#
# ### Subtask:
# Consider techniques like oversampling or undersampling for the `TenYearCHD` variable.

# %% [markdown]
# **Reasoning**:
# Check the distribution of the target variable `TenYearCHD` again to confirm the class imbalance.

# %%
display(df_encoded['TenYearCHD'].value_counts())
# Out:
# TenYearCHD
# 0    2879
# 1     511
# Name: count, dtype: int64

# %% [markdown]
# **Reasoning**:
# Import a suitable oversampling technique from imblearn.over_sampling, separate the features (X) and the target variable (y) from the df_encoded DataFrame, and apply the chosen oversampling technique to create balanced datasets for training.

# %%
from imblearn.over_sampling import SMOTE

X = df_encoded.drop('TenYearCHD', axis=1)
y = df_encoded['TenYearCHD']

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

print("Shape of original features:", X.shape)
print("Shape of resampled features:", X_resampled.shape)
print("\nDistribution of the target variable before oversampling:")
display(y.value_counts())
print("\nDistribution of the target variable after oversampling:")
display(y_resampled.value_counts())
# Out:
# Shape of original features: (3390, 16)
# Shape of resampled features: (5758, 16)
#
# Distribution of the target variable before oversampling:
# TenYearCHD
# 0    2879
# 1     511
# Name: count, dtype: int64
# Distribution of the target variable after oversampling:
# TenYearCHD
# 1    2879
# 0    2879
# Name: count, dtype: int64

# %% [markdown]
# ## Feature selection or engineering
#
# ### Subtask:
# Perform feature selection or engineering on the resampled data.

# %% [markdown]
# ## Split the data
#
# ### Subtask:
# Split the resampled data (`X_resampled` and `y_resampled`) into training and testing sets.

# %% [markdown]
# **Reasoning**:
# Import the necessary function and split the resampled data into training and testing sets, then print the shapes.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (4606, 16)
# Shape of X_test: (1152, 16)
# Shape of y_train: (4606,)
# Shape of y_test: (1152,)

# %% [markdown]
# ## Build a predictive model
#
# ### Subtask:
# Choose and train a suitable model (e.g., Logistic Regression, Random Forest) to predict `TenYearCHD`.

# %% [markdown]
# **Reasoning**:
# Import the necessary model class and train the model using the training data.

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# ## Evaluate the model
#
# ### Subtask:
# Evaluate the performance of the trained model using appropriate metrics.

# %% [markdown]
# **Reasoning**:
# Calculate and display the evaluation metrics for the trained model on the test set.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

y_pred = model.predict(X_test)
y_pred_proba = model.predict_proba(X_test)[:, 1]

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_proba)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"AUC Score: {auc:.4f}")
# Out:
# Accuracy: 0.8724
# Precision: 0.8866
# Recall: 0.8472
# F1 Score: 0.8665
# AUC Score: 0.9449

# %% [markdown]
# ## Interpret the model
#
# ### Subtask:
# Understand which features are most important for prediction.

# %% [markdown]
# **Reasoning**:
# Access, sort, and display the feature importances from the trained model.

# %%
import pandas as pd

feature_importances = pd.Series(model.feature_importances_, index=X_train.columns)
sorted_feature_importances = feature_importances.sort_values(ascending=False)

display("Top 10 Most Important Features:")
display(sorted_feature_importances.head(10))
# Out:
# 'Top 10 Most Important Features:'
# age           0.138171
# sysBP         0.112376
# education     0.098619
# cigsPerDay    0.087268
# id            0.080168
# totChol       0.078809
# glucose       0.073481
# diaBP         0.072180
# heartRate     0.070820
# BMI           0.068225
# dtype: float64

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   Before imputation, missing values were present in `education` (87), `cigsPerDay` (22), `BPMeds` (44), `totChol` (38), `BMI` (14), `heartRate` (1), and `glucose` (304). After imputation using the mean, there were no remaining missing values in these columns.
# *   Categorical features 'sex' and 'is_smoking' were successfully one-hot encoded, resulting in new columns `sex_M` and `is_smoking_YES`.
# *   The original dataset had a significant class imbalance in the `TenYearCHD` variable, with 2879 instances for class 0 and 511 for class 1. After applying SMOTE oversampling, the dataset became balanced with 2879 instances for each class, and the total number of instances increased from 3390 to 5758.
# *   The resampled data was split into training (80% - 4606 instances) and testing (20% - 1152 instances) sets.
# *   A Random Forest Classifier model was trained to predict `TenYearCHD`.
# *   The model evaluation metrics on the test set are: Accuracy: 0.8724, Precision: 0.8866, Recall: 0.8472, F1 Score: 0.8665, and AUC Score: 0.9449.
# *   The top 10 most important features for predicting `TenYearCHD` according to the Random Forest model are: `age`, `sysBP`, `education`, `cigsPerDay`, `id`, `totChol`, `glucose`, `diaBP`, `heartRate`, and `BMI`.
#
# ### Insights or Next Steps
#
# *   The high AUC score (\$0.9449\$) suggests that the trained Random Forest model has strong discriminative power for predicting the ten-year risk of coronary heart disease.
# *   Further analysis could involve exploring the relationships between the top influential features identified (such as age, systolic blood pressure, and education) and the risk of CHD to gain deeper domain insights.
